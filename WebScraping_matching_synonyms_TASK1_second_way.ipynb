# %% [markdown]
# From this link was scraped a list of chemicals compounds which counts 1976 rows.(https://en.wikipedia.org/wiki/List_of_CAS_numbers_by_chemical_compound) This is a list of CAS numbers by chemical formulas and chemical compounds, indexed by formula.The CAS number is a unique number applied to a specific chemical by the Chemical Abstracts Service (CAS).

# %%
# !pip install pandas beautifulsoup4 # To execute folowing codes, you'll need to install the requests and beautifulsoup4 libraries.
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_CAS_numbers_by_chemical_compound"

# Send an HTTP request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all tables on the page
    tables = soup.find_all('table')

    # Initialize an empty list to store DataFrames
    all_dfs = []

    # Iterate through each table
    for i, table in enumerate(tables):
        # Extract data from the table
        data = []
        for row in table.find_all('tr')[1:]:  # Skip the header row
            columns = row.find_all(['th', 'td'])
            data.append([col.get_text(strip=True) for col in columns])

        # Create a DataFrame from the extracted data
        df = pd.DataFrame(data, columns=["Chemical formula", "Chemical Name", "CAS number"])

        # Append the DataFrame to the list
        all_dfs.append(df)

        # Print the DataFrame for each table
        print(f"Table {i + 1}:\n{df}\n{'=' * 50}\n")

    # Concatenate all DataFrames into one
    final_df = pd.concat(all_dfs, ignore_index=True)

    # Print the final concatenated DataFrame
    print("Final Concatenated DataFrame:\n", final_df)

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Table 1:
#     Chemical formula                Chemical Name  CAS number
# 0              Ac2O3          actinium(III) oxide  12002-61-8
# 1                 Ag                       silver   7440-22-4
# 2            AgAlCl4  silver tetrachloroaluminate  27039-77-6
# 3               AgBr               silver bromide   7785-23-1
# 4             AgBrO3               silver bromate   7783-89-3
# ..               ...                          ...         ...
# 114       Au2(SeO4)3           gold(III) selenate  10294-32-3
# 115           Au2Se3           gold(III) selenide   1303-62-4
# 116           Au4Cl8         gold(I,III) chloride  62792-24-9
# 117            Au4F8         gold(I,III) fluoride  14270-21-4
# 118                                          None        None
#
# [119 rows x 3 columns]
# ==================================================
#
# Table 2:
#     Chemical formula          Chemical Name  CAS number
# 0                BAs         boron arsenide  12005-69-5
# 1              BAsO4         boron arsenate  13510-31-1
# 2               BBr3       boron tribromide  10294-33-4
# 3               BCl3      boron trichloride  10294-34-5
# 4                BF3      boron trifluoride   7637-07-2
# ..               ...                    ...         ...
# 137             BrF3    bromine trifluoride   7787-71-5
# 138             BrF5  bromine pentafluoride   7789-30-2
# 139             BrN3          bromine azide  13973-87-0
# 140             BrO2        bromine dioxide  21255-83-4
# 141             Br2O       bromine monoxide  21308-80-5
#
# [142 rows x 3 columns]
# ==================================================
#
# Table 3:
#     Chemical formula                          Chemical Name  CAS number
# 0         C10H16N2O8  Ethylenediaminetetraacetic acid(EDTA)   6381-92-6
# 1          C12H22O11                                sucrose     57-50-1
# 2          C20H25N30        Lysergic acid diethylamide(LSD)     50-37-3
# 3     C123H193N35O37    Common serum albumin(macromolecule)   9048-49-1
# 4          Ca(AlH4)2            calcium tetrahydroaluminate  16941-10-9
# ..               ...                                    ...         ...
# 267          Cu2P2O7               copper(II) pyrophosphate  10102-90-6
# 268             Cu2S                      copper(I) sulfide  22205-45-4
# 269            Cu2Se                     copper(I) selenide  20405-64-5
# 36              EuS              europium(II) sulfide  12020-65-4
# 37             EuSe             europium(II) selenide  12020-66-5
# 38            EuSi2             europium(II) silicide  12434-24-1
# 39             EuTe            europium(II) telluride  12020-69-8
# 40            EuVO4             europium(II) vanadate  13537-11-6
# 41            Eu2O3               europium(III) oxide   1308-96-9
# 42        Eu2(SO4)3             europium(III) sulfate  13537-15-0
# ==================================================
#
# Table 6:
#    Chemical formula                   Chemical Name  CAS number
# 0              FNO3                fluorine nitrate   7789-26-6
# 1            FOClO3            fluorine perchlorate  10049-03-3
# 2               F2O               fluorine monoxide   7783-41-7
# 3              F2O2                fluorine dioxide   7783-44-0
# 4                Fe                            iron   7439-89-6
# 5         Fe(AlO2)2              iron(II) aluminate  12068-49-4
# 6              FeAs               iron(III) arsenic  12044-16-5
# 7             FeBr2                iron(II) bromide   7789-46-0
# 8             FeBr3               iron(III) bromide  10031-26-2
# 9             FeCO3              iron(II) carbonate    563-71-3
# 10      Fe(C2H3O2)2                iron(II) acetate   3094-87-9
# 11            FeCl2               iron(II) chloride   7758-94-3
# 12       FeCl2•2H2O     iron(II) chloride dihydrate  16399-77-2
# 13       FeCl2•4H2O  iron(II) chloride tetrahydrate  13478-10-9
# 14            FeCl3              iron(III) chloride   7705-08-0
# 15       FeCl3•6H2O  iron(III) chloride hexahydrate  10025-77-1
# 16          FeCr2O4                   iron chromite   1308-31-2
# 17             FeF2               iron(II) fluoride   7789-28-8
# 18        FeF2•4H2O  iron(II) fluoride tetrahydrate  13940-89-1
# 19             FeF3              iron(III) fluoride   7783-50-8
# 20        FeF3•3H2O   iron(III) fluoride trihydrate  15469-38-2
# 21       Fe(H2PO2)3         iron(III) hypophosphite   7783-84-8
# 22             FeI2                 iron(II) iodide   7783-86-0
# 23             FeI3                iron(III) iodide  15600-49-4
# 24           FeMoO4              iron(II) molybdate  13718-70-2
# 25         Fe(NO3)2                iron(II) nitrate  14013-86-6
# 26         Fe(NO3)3                  ferric nitrate  10421-48-4
# 27              FeO                  iron(II) oxide   1345-25-1
# 28          Fe(OH)2              iron(II) hydroxide  18624-44-7
# 29          Fe(OH)3             iron(III) hydroxide   1309-33-7
# 30            FePO4             iron(III) phosphate  10045-86-0
# 31              FeS                iron(II) sulfide   1317-37-9
# 32            FeSO4                iron(II) sulfate   7720-78-7
# 33             FeSe               iron(II) selenide   1310-32-3
# 34             FeTe              iron(II) telluride  12125-63-2
# 35           FeTiO4               iron(II) titanate  12168-52-4
# 36         Fe(VO3)3          iron(III) metavanadate  65842-03-7
# 37            FeWO4              iron(II) tungstate  13870-24-1
# 38       Fe2(C2O4)3               iron(III) oxalate  19469-07-9
# 39       Fe2(CrO4)3              iron(III) chromate  10294-52-7
# 40      Fe2(Cr2O7)3            iron(III) dichromate  10294-53-8
# 41            Fe2O3                 iron(III) oxide   1309-37-1
# 42        Fe2(SO4)3               iron(III) sulfate  10028-22-5
# 43          Fe2SiO4          iron(II) orthosilicate  10179-73-4
# 44            Fe3O4              iron(II,III) oxide   1317-61-9
# 45        Fe3(PO4)2              iron(II) phosphate  14940-41-1
# 49              GeS                 germanium(II) sulfide  12025-32-0
# 50             GeS2                 germanium(IV) sulfide  12025-34-2
# 51             GeSe                germanium(II) selenide  12065-10-0
# 52            GeSe2                germanium(IV) selenide  12065-11-1
# 53             GeTe               germanium(II) telluride  12025-39-7
# 54            Ge3N4                 germanium(IV) nitride  12065-36-0
# ==================================================
#
# Table 8:
#    Chemical formula            Chemical Name  CAS number
# 0               H2O                    water   7732-18-5
# 1             H2SO4            sulfuric acid   7664-93-9
# 2             H3BO3               boric acid  10043-35-3
# 3              HfB2           hafnium boride  12007-23-7
# 4             HfBr4          hafnium bromide  13777-22-5
# 5               HfC          hafnium carbide  12069-85-1
# 6             HfCl4         hafnium chloride  13499-05-3
# 7              HfF4     hafnium(IV) fluoride  13709-52-9
# 8              HfH2          hafnium hydride  12770-26-2
# 9              HfI3           hafnium iodide  13779-73-2
# 10              HfN          hafnium nitride  25817-87-2
# 11             HfO2            hafnium oxide  12055-23-1
# 12              HfP        hafnium phosphide  12325-59-6
# 13         Hf(SO4)2          hafnium sulfate  15823-43-5
# 14             HfS2          hafnium sulfide  18855-94-2
# 15            HfSe2         hafnium selenide  12162-21-9
# 16           HfSiO4    hafnium orthosilicate  13870-13-8
# 17            HfSi2         hafnium silicide  12401-56-8
# 18            HgBr2      mercury(II) bromide   7789-47-1
# 19      Hg(C2H3O2)2      mercury(II) acetate   1600-27-7
# 20            HgCl2     mercury(II) chloride   7487-94-7
# 21          HgCl2O8  mercury(II) perchlorate  73491-34-6
# 22             HgF2     mercury(II) fluoride   7783-39-3
# 23             HgH2      mercury(II) hydride  72172-67-9
# 24         Hg(IO3)2       mercury(II) iodate   7783-32-6
# 25             HgI2       mercury(II) iodide   7774-29-0
# 26         Hg(NO3)2      mercury(II) nitrate  10045-94-0
# 27              HgO        mercury(II) oxide  21908-53-2
# 28         Hg(ONC)2    mercury(II) fulminate    628-86-4
# 29              HgS      mercury(II) sulfide   1344-48-5
# 30         Hg(SCN)2  mercury(II) thiocyanate    592-85-8
# 31            HgSO4      mercury(II) sulfate   7783-35-9
# 32             HgSe     mercury(II) selenide  20601-83-6
# 33             HgTe    mercury(II) telluride  12068-90-5
# 34           Hg2Br2       mercury(I) bromide  15385-58-7
# 35           Hg2Cl2      mercury(I) chloride  10112-91-1
# 36            Hg2F2      mercury(I) fluoride   1396-75-4
# 37            Hg2I2        mercury(I) iodide  15385-57-6
# 38             Hg2O         mercury(I) oxide  15829-53-5
# 39            HoBr3          holmium bromide  13825-76-8
# 40        Ho(CHO2)3          holmium formate   3252-59-3
# 41            HoCl3         holmium chloride  10138-62-2
# 42             HoF3         holmium fluoride  13760-78-6
# 43             HoI3           holmium iodide  13813-41-7
# 44              HoN          holmium nitride  12029-81-1
# 45            HoSi2         holmium silicide  12136-24-2
# 46            HoVO4         holmium vanadate  13977-63-4
# 47            Ho2O3            holmium oxide  12055-62-8
# 48            Ho2S3          holmium sulfide  12162-59-3
# ==================================================
#
# Table 9:
#    Chemical formula                     Chemical Name  CAS number
# 0               IBr                iodine monobromide   7789-33-5
#    Chemical formula                   Chemical Name  CAS number
# 0             KAlF4  potassium tetrafluoroaluminate  14484-69-6
# 1             KAlO2             potassium aluminate  12003-63-3
# 2              KBF4          potassium fluoroborate  14075-53-7
# 3               KBr               potassium bromide   7758-02-3
# 4             KBrO3               potassium bromate   7758-01-2
# ..              ...                             ...         ...
# 69           K3AlF6   potassium hexafluoroaluminate  13775-52-5
# 70      K3(Fe(CN)6)          potassium ferricyanide  13746-66-2
# 71            K3PO4             potassium phosphate   7778-53-2
# 72           K4P2O7         potassium pyrophosphate   7320-34-5
# 73             KrF2              krypton difluoride  13773-81-4
#
# [74 rows x 3 columns]
# ==================================================
#
# Table 11:
#    Chemical formula        Chemical Name  CAS number
# 0            LaAlO3  lanthanum aluminate  71496-78-1
# 1              LaB6     lanthanum boride  12008-21-8
# 2             LaBr3    lanthanum bromide  13536-79-3
# 3         La(CHO2)3    lanthanum formate   2081-11-0
# 4              LaC2    lanthanum carbide  12071-15-7
# ..              ...                  ...         ...
# 69              LuN     lutetium nitride  12125-25-6
# 70         Lu(NO3)3     lutetium nitrate  36549-50-5
# 71            Lu2O3       lutetium oxide  12032-20-1
# 72            Lu2S3     lutetium sulfide  12163-20-1
# 73           Lu2Te3   lutetium telluride  12163-22-3
#
# [74 rows x 3 columns]
# ==================================================
#
# Table 12:
#    Chemical formula                  Chemical Name  CAS number
# 0             MgBr2              magnesium bromide   7789-48-2
# 1        MgBr2•6H2O  magnesium bromide hexahydrate  13446-53-2
# 2             MgCO3            magnesium carbonate    546-93-0
# 3       Mg(C2H2O2)2            magnesium succinate    556-32-1
# 4         MgC3H9O6P     magnesium glycerophosphate    927-20-8
# ..              ...                            ...         ...
# 73            MoSi2        molybdenum(IV) silicide  12136-78-6
# 74            MoTe2       molybdenum(IV) telluride  12058-20-7
# 75            Mo2O3          molybdenum(III) oxide   1313-29-7
# 76            Mo2O5            molybdenum(V) oxide  12163-73-4
# 77            Mo2S3        molybdenum(III) sulfide  12033-33-9
#
# [78 rows x 3 columns]
# ==================================================
#
# Table 13:
#     Chemical formula           Chemical Name   CAS number
# 0               NBr3     nitrogen tribromide   15162-90-0
# 1               NCl3    nitrogen trichloride   10025-85-1
# 2                NF3    nitrogen trifluoride    7783-54-2
# 3                NH3                 ammonia    7664-41-7
# 4              NH4Cl       ammonium chloride   12125-02-9
# ..               ...                     ...          ...
# 196              NpN  neptunium(III) nitride   12058-90-1
# 197              NpO     neptunium(II) oxide   12202-03-8
# 198             NpO2     neptunium(IV) oxide   12035-79-9
# 199            Np2O5      neptunium(V) oxide  121433-01-0
# 200            Np2S3  neptunium(III) sulfide   12281-24-2
#
# [201 rows x 3 columns]
# ==================================================
#
# Table 14:
#    Chemical formula                    Chemical Name   CAS number
# 0               OF2              oxygen(II) fluoride    7783-41-7
# 1              O2F2               oxygen(I) fluoride    7783-44-0
# 2             OsBr3              osmium(III) bromide   59201-51-3
# 3             OsBr4               osmium(IV) bromide   59201-52-4
# 4         Os(C5H5)2     osmium(II) cyclopentadienide    1273-81-0
# 5             OsCl3             osmium(III) chloride   13444-93-4
# 6        OsCl3•3H2O  osmium(III) chloride trihydrate  114268-63-2
# 7             OsCl4              osmium(IV) chloride   10026-01-4
# 8             OsCl5               osmium(V) chloride   71328-74-0
# 9              OsF4              osmium(IV) fluoride   54120-05-7
# 10          (OsF5)4               osmium(V) fluoride   31576-40-6
# 11             OsF6              osmium(VI) fluoride   13768-38-2
# 12             OsF7             osmium(VII) fluoride   16949-69-2
# 13             OsF8            osmium(VIII) fluoride   18432-81-0
# 14              OsI                 osmium(I) iodide   76758-38-8
# 15             OsI2                osmium(II) iodide   59201-57-9
# 16             OsI3               osmium(III) iodide   59201-58-0
# 17             OsO2                 osmium(IV) oxide   12036-02-1
# 18             OsO4               osmium(VIII) oxide   20816-12-0
# 19             OsS2               osmium(IV) sulfide   12137-61-0
# 20            OsSe2              osmium(IV) selenide   12310-19-9
# 21            OsTe2             osmium(IV) telluride   12166-21-1
# ==================================================
#
# Table 15:
#     Chemical formula             Chemical Name  CAS number
# 0               PBr3     phosphorus tribromide   7789-60-8
# 1               PBr5   phosphorus pentabromide   7789-69-7
# 2               PCl3    phosphorus trichloride   7719-12-2
# 3               PCl5  phosphorus pentachloride  10026-13-8
# 4                PF3    phosphorus trifluoride   7783-55-3
# ..               ...                       ...         ...
# 160             PuO2       plutonium(IV) oxide  12059-95-9
# 161              PuS     plutonium(II) sulfide  12038-51-6
# 162             PuS2     plutonium(IV) sulfide  12038-56-1
# 163             PuSe    plutonium(II) selenide  23299-88-9
# 164            Pu2O3      plutonium(III) oxide  12036-34-9
#
# [165 rows x 3 columns]
# ==================================================
#
# Table 16:
#    Chemical formula            Chemical Name  CAS number
# 0             RaBr2           radium bromide  10031-23-9
# 1             RaCO3         radium carbonate   7116-98-5
# 2             RaCl2          radium chloride  10025-66-8
# 3              RaF2          radium fluoride  20610-49-5
# 4              RaI2            radium iodide  20610-52-0
# ..              ...                      ...         ...
# 75             RuO2      ruthenium(IV) oxide  12036-10-1
# 76             RuO4      ruthenium(VI) oxide  20427-56-9
# 77             RuS2    ruthenium(IV) sulfide  12166-20-0
# 78            RuSe2   ruthenium(IV) selenide  12166-21-1
# 79            RuTe2  ruthenium(IV) telluride  12166-21-1
#
# [80 rows x 3 columns]
# ==================================================
#
# Table 17:
#     Chemical formula         Chemical Name  CAS number
# 0               SCl2     sulfur dichloride  10545-99-0
# 1               SCl4  sulfur tetrachloride  13451-08-6
# 2                SF2     sulfur difluoride  13814-25-0
# 3                SF4  sulfur tetrafluoride   7783-60-0
# 4                SF6   sulfur hexafluoride   2551-62-4
# ..               ...                   ...         ...
# 128           SrSnO3    strontium stannate  12143-34-9
# 129           SrTiO3    strontium titanate  12060-59-2
# 130            SrWO4   strontium tungstate  13451-05-3
# 131           SrZrO3   strontium zirconate  12036-39-4
# 132            Sr3P2   strontium phosphide  12504-16-4
#
# [133 rows x 3 columns]
# ==================================================
#
# Table 18:
#     Chemical formula            Chemical Name  CAS number
# 0              TaAl3  tantalum(III) aluminide  12004-76-1
# 1              TaBr3    tantalum(III) bromide  13842-73-4
# 2              TaBr4     tantalum(IV) bromide  13842-76-7
# 3              TaBr5      tantalum(V) bromide  13451-11-1
# 4                TaC     tantalum(IV) carbide  12070-06-3
# ..               ...                      ...         ...
# 138             TmI2       thulium(II) iodide  60864-26-8
# 139             TmI3      thulium(III) iodide  13813-43-9
# 140        Tm(NbO3)2      thulium(II) niobate  97086-52-7
# 141            Tm2O3       thulium(III) oxide  12036-44-1
# 142            Tm2S3     thulium(III) sulfide  12166-30-2
#
# [143 rows x 3 columns]
# ==================================================
#
# Table 19:
#    Chemical formula          Chemical Name  CAS number
# 0              UBr3   uranium(III) bromide  13470-19-4
# 1              UBr4    uranium(IV) bromide  13470-20-7
# 2              UBr5     uranium(V) bromide  13775-16-1
# 3                UC    uranium(IV) carbide  12070-09-6
# 4               UC2    uranium(VI) carbide  12071-33-9
# 5              UCl3  uranium(III) chloride  10025-93-1
# 6              UCl4   uranium(IV) chloride  10026-10-5
# 7              UCl5    uranium(V) chloride  13470-21-8
# 8              UCl6   uranium(VI) chloride  13763-23-0
# 9               UF3  uranium(III) fluoride  13775-06-9
# 10              UF4   uranium(IV) fluoride  10049-14-6
# 11              UF5    uranium(V) fluoride  13775-07-0
# 12              UF6   uranium(VI) fluoride   7783-81-5
# 13              UH3   uranium(III) hydride  13598-56-6
# 14              UI3    uranium(III) iodide  13775-18-3
# 15              UI4     uranium(IV) iodide  13470-22-9
# 16               UN   uranium(III) nitride  25658-43-9
# 17               UO      uranium(II) oxide  13598-56-6
# 18              UO2      uranium(IV) oxide   1344-57-6
# 19        UO2(NO3)2         uranyl nitrate  10102-06-4
# 20              UO3      uranium(VI) oxide   1344-58-7
# 21               US    uranium(II) sulfide  12039-11-1
# 22             USe3   uranium(VI) selenide  12138-23-7
# 23             UTe2  uranium(IV) telluride  12138-37-3
# 24             UTe3  uranium(VI) telluride  12040-18-5
# 25             U2O5       uranium(V) oxide  12065-66-6
# 26             U2S3    uranium(II) sulfide  12138-13-5
# 27             U3N2    uranium(II) nitride  12033-85-1
# 28             U3O8    uranium(V,VI) oxide   1344-59-8
# 29             U4O9    uranium(IV,V) oxide  12037-15-9
# ==================================================
#
# Table 20:
#    Chemical formula               Chemical Name  CAS number
# 0              VBr2        vanadium(II) bromide  14890-41-6
# 1              VBr3       vanadium(III) bromide  13470-26-3
# 2              VBr4        vanadium(IV) bromide  13595-30-7
# 3                VC        vanadium(IV) carbide  12070-10-9
# 4              VCl2       vanadium(II) chloride  10580-52-6
# 5              VCl3      vanadium(III) chloride   7718-98-1
# 6              VCl4       vanadium(IV) chloride   7632-51-1
# 7               VF2       vanadium(II) fluoride  13842-80-3
# 8               VF3      vanadium(III) fluoride  10049-12-4
# 9               VF4       vanadium(IV) fluoride  10049-16-8
# 10              VF5        vanadium(V) fluoride   7783-72-4
# 11               VH         vanadium(I) hydride  13966-93-3
# 12              VI2         vanadium(II) iodide  15513-84-5
# 13              VI3        vanadium(III) iodide  15513-94-7
# 14              VI4         vanadium(IV) iodide  15831-18-2
# 15               VN       vanadium(III) nitride  24646-85-3
# 3                AgBr               silver bromide   7785-23-1
# 4              AgBrO3               silver bromate   7783-89-3
# ...               ...                          ...         ...
# 1971            ZrSe2       zirconium(IV) selenide  12166-47-1
# 1972            ZrSi2       zirconium(IV) silicide  12039-90-6
# 1973           ZrSiO4       zirconium(IV) silicate  10101-52-7
# 1974            ZrTe2      zirconium(IV) telluride  32321-65-6
# 1975         Zr(WO4)2      zirconium(IV) tungstate  16853-74-0
#
# [1976 rows x 3 columns]

# %%
final_df.head() # how it looks that table from wikipedia
# Out:
#   Chemical formula                Chemical Name  CAS number
# 0            Ac2O3          actinium(III) oxide  12002-61-8
# 1               Ag                       silver   7440-22-4
# 2          AgAlCl4  silver tetrachloroaluminate  27039-77-6
# 3             AgBr               silver bromide   7785-23-1
# 4           AgBrO3               silver bromate   7783-89-3

# %%
final_df.info() # info about that table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1976 entries, 0 to 1975
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Chemical formula  1976 non-null   object
#  1   Chemical Name     1975 non-null   object
#  2   CAS number        1975 non-null   object
# dtypes: object(3)
# memory usage: 46.4+ KB

# %%
final_df.to_csv('/content/final_df.csv', index = False)# we downloaded this table in excel format, you have it in the folder

# %%
chemicals = pd.read_csv('/content/df_TIM1_FINAL.csv')
chemicals.head() # Task1 the first way, when we handle the Kungul database
# Out:
#   IngredientIdentifier                                               Name  \
# 0               G00001  saccharomycesleuconostocapple fruitcarrot root...
# 1               G00002  lactobacilluscentella asiaticagleditsia sinens...
# 2               G00003  bacilluscordyceps sinensisganoderma lucidumino...
# 3               G00004                         ziziphus spinachristi leaf
# 4               G00005                          zingiber officinale water
#
#    Carcinogens  EndocrineDisruptors  Allergen  SkinIrritant Synonyms
# 0        False                False     False         False      NaN
# 1        False                False     False         False      NaN
# 2        False                False     False         False      NaN
# 3        False                False     False         False      NaN
# 4        False                False     False         False      NaN

# %%
chemicals_synonyms = chemicals.copy()

# %%
import pandas as pd
import gensim
import gensim.downloader as api
from gensim.models import KeyedVectors
from tqdm import tqdm  # For progress bar

# %% [markdown]
# PubChemPy is a Python library that provides a programmatic interface to access chemical information from the PubChem database. PubChem is a free chemistry database maintained by the National Center for Biotechnology Information (NCBI), which is part of the National Institutes of Health (NIH).
#
# With PubChemPy, you can retrieve information about chemical compounds, search for compounds based on various criteria, and access data such as chemical properties, identifiers, and biological activities.

# %%
# !pip install pubchempy
# Out:
# Collecting pubchempy
#   Downloading PubChemPy-1.0.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pubchempy
#   Building wheel for pubchempy (setup.py) ... done
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13819 sha256=765c75134c9c36fe33bb759f651f104b39971b613178361f798b2381950b229f
#   Stored in directory: /root/.cache/pip/wheels/90/7c/45/18a0671e3c3316966ef7ed9ad2b3f3300a7e41d3421a44e799
# Successfully built pubchempy
# Installing collected packages: pubchempy
# Successfully installed pubchempy-1.0.4

# %% [markdown]
# This is an example how we can access a data for certain chemical compound.

# %%
import pubchempy as pcp

def get_synonyms(compound_name):
    # Search for the compound by name
    compound = pcp.get_compounds(compound_name, 'name', record_type='3d')[0]

    # Get synonyms from the compound data
    synonyms = compound.synonyms

    return synonyms

# Example usage
compound_name = "aspirin"
synonyms = get_synonyms(compound_name)

# Print the synonyms
print(f"Synonyms for {compound_name}: {synonyms}")
# Out:
# Synonyms for aspirin: ['aspirin', 'ACETYLSALICYLIC ACID', '50-78-2', '2-Acetoxybenzoic acid', '2-(Acetyloxy)benzoic acid', 'Acetylsalicylate', 'O-Acetylsalicylic acid', 'o-Acetoxybenzoic acid', 'Acenterine', 'Acetophen', 'Acetosal', 'Acylpyrin', 'Easprin', 'Ecotrin', 'Salicylic acid acetate', 'Acetosalin', 'Aspirdrops', 'Polopiryna', 'Salcetogen', 'Aceticyl', 'Acetonyl', 'Acetylin', 'Acidum acetylsalicylicum', 'Benaspir', 'Colfarit', 'Empirin', 'Endydol', 'Measurin', 'Rhodine', 'Saletin', 'o-Carboxyphenyl acetate', 'Enterosarein', 'Enterosarine', 'Acetisal', 'Acetylsal', 'Aspirine', 'Bialpirinia', 'Entericin', 'Enterophen', 'Micristin', 'Pharmacin', 'Premaspin', 'Salacetin', 'Solpyron', 'Temperal', 'Acesal', 'Acisal', 'Asagran', 'Asteric', 'Duramax', 'Ecolen', 'Extren', 'Globoid', 'Helicon', 'Idragin', 'Rhonal', 'Aspro', 'Novid', 'Rheumintabletten', 'Yasta', 'Solprin acid', 'Benzoic acid, 2-(acetyloxy)-', 'Acimetten', 'Bialpirina', 'Claradin', 'Clariprin', 'Delgesic', 'Entrophen', 'Globentyl', 'Neuronika', 'Acetilum acidulatum', 'Cemirit', 'Decaten', 'Levius', 'Pirseal', 'Solfrin', 'Acetilsalicilico', 'Adiro', 'Aspec', 'Acetosalic acid', '2-acetyloxybenzoic acid', 'Dolean pH 8', 'Triple-sal', 'Spira-Dine', 'ZORprin', 'Contrheuma retard', 'Bi-prin', 'XAXA', 'Acido acetilsalicilico', 'Acide acetylsalicylique', 'Persistin', 'Bayer', '2-Carboxyphenyl acetate', 'A.S.A. empirin', 'ASA', '8-hour Bayer', 'Endosprin', 'Kapsazal', 'Asatard', 'Durlaza', 'Bayer Plus', 'Acetylsalicylsaure', 'Rheumin tabletten', 'Solprin', 'Tasprin', 'Nu-seals aspirin', 'Salicylic acid, acetate', 'Acido O-acetil-benzoico', 'Kyselina acetylsalicylova', '2-Acetoxybenzenecarboxylic acid', 'Acetylsalicylsaeure', 'Azetylsalizylsaeure', 'SP 189', 'St. Joseph Aspirin for Adults', 'A.S.A.', 'St. Joseph', 'Kyselina 2-acetoxybenzoova', 'AC 5230', 'Acetylsalicyclic acid', 'Acetylsalicylicum acidum', 'Aspropharm', 'Cardioaspirin', 'Acetard', 'CHEBI:15365', 'acetyl salicylate', 'S-211', 'ECM', 'NSC-27223', 'acide 2-(acetyloxy)benzoique', 'Bayer Extra Strength Aspirin for Migraine Pain', 'Aspirin (Standard)', 'NSC-406186', 'R16CO5Y76E', 'DTXSID5020108', '2-(acetyloxy)benzoate', 'o-(Acetyloxy)benzoic acid', 'benzoic acid, 2-acetoxy-', 'BAY1019036', 'DTXCID50108', 'Acetylsalicylic acid (who-ip)', 'AXOTAL COMPONENT ASPIRIN', 'AZDONE COMPONENT ASPIRIN', 'CODOXY COMPONENT ASPIRIN', 'AGGRENOX COMPONENT ASPIRIN', 'Aspirin form II', 'DUOCOVER COMPONENT ASPIRIN', 'EXCEDRIN COMPONENT ASPIRIN', 'FIORINAL COMPONENT ASPIRIN', 'NORGESIC COMPONENT ASPIRIN', 'PERCODAN COMPONENT ASPIRIN', 'Q-GESIC COMPONENT ASPIRIN', 'ROXIPRIN COMPONENT ASPIRIN', 'VICOPRIN COMPONENT ASPIRIN', 'YOSPRALA COMPONENT ASPIRIN', 'DUOPLAVIN COMPONENT ASPIRIN', 'EQUAGESIC COMPONENT ASPIRIN', 'INVAGESIC COMPONENT ASPIRIN', 'LANORINAL COMPONENT ASPIRIN', 'MICRAININ COMPONENT ASPIRIN', 'ROBAXISAL COMPONENT ASPIRIN', 'component of Midol', 'ASPIRIN COMPONENT OF AXOTAL', 'ASPIRIN COMPONENT OF AZDONE', 'ASPIRIN COMPONENT OF CODOXY', 'NSC27223', 'ORPHENGESIC COMPONENT ASPIRIN', 'ASPIRIN COMPONENT OF AGGRENOX', 'ASPIRIN COMPONENT OF DUOCOVER', 'ASPIRIN COMPONENT OF EXCEDRIN', 'ASPIRIN COMPONENT OF FIORINAL', 'ASPIRIN COMPONENT OF NORGESIC', 'ASPIRIN COMPONENT OF PERCODAN', 'ASPIRIN COMPONENT OF Q-GESIC', 'ASPIRIN COMPONENT OF ROXIPRIN', 'ASPIRIN COMPONENT OF VICOPRIN', 'ASPIRIN COMPONENT OF YOSPRALA', 'SYNALGOS-DC COMPONENT ASPIRIN', 'component of Synirin', 'ASPIRIN COMPONENT OF DUOPLAVIN', 'ASPIRIN COMPONENT OF EQUAGESIC', 'ASPIRIN COMPONENT OF INVAGESIC', 'ASPIRIN COMPONENT OF LANORINAL', 'ASPIRIN COMPONENT OF MICRAININ', 'ASPIRIN COMPONENT OF ROBAXISAL', 'MFCD00002430', 'NSC406186', 'component of Zactirin', 'MEPRO-ASPIRIN COMPONENT ASPIRIN', 'PERCODAN-DEMI COMPONENT ASPIRIN', 'PRAVIGARD PAC COMPONENT ASPIRIN', 'SOMA COMPOUND COMPONENT ASPIRIN', 'ASPIRIN COMPONENT OF ORPHENGESIC', 'component of Coricidin', 'component of Persistin', 'component of Robaxisal', 'o-Acetoxybenzoate', 'ASPIRIN COMPONENT OF SYNALGOS-DC', 'DARVO ...

# %% [markdown]
# The same logic we apply here, when we want to access synonyms for every chemical compound/name in our database, previos updated.

# %%
import pandas as pd
import pubchempy as pcp

def get_synonyms(chemical_name):
    try:
        # Search for the compound by name
        compound = pcp.get_compounds(chemical_name, 'name', record_type='3d')

        if compound:
            # If compound is found, return synonyms
            return compound[0].synonyms
        else:
            # If compound is not found, return an empty list
            return []
    except pcp.PubChemHTTPError as e:
        # Handle PubChemHTTPError when there is an issue with the PubChem server
        print(f"PubChemHTTPError: {e}")
        return []
    except Exception as e:
        # Handle other exceptions
        print(f"Error: {e}")
        return []

# Create an empty list to store synonyms
all_synonyms = []

# Iterate through each chemical name in the 'Name' column
for chemical_name in chemicals['Name']:
    # Get synonyms for the current chemical name
    synonyms = get_synonyms(chemical_name)

    # Append synonyms to the list
    all_synonyms.append(synonyms)

# Print or use the list of synonyms as needed
print(all_synonyms)
# Out:
# Error: 'float' object is not iterable
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# all_synonyms_df is dataframe which is made by previous code with access to PubChem database, and it contains synonyms for approximately 1300 chemical compounds.

# %%
all_synonyms_df = pd.DataFrame({'Synonyms': all_synonyms}) # make a dataframe from the output

# Concatenate along columns (axis=1)
final = pd.concat([chemicals_synonyms, all_synonyms_df], axis=1) # make a concatenation with our previos database

# %% [markdown]
# Kako izgleda dataframe na sostojki sinonimi koi gi dobivme so pomosh na webscraping.

# %%
all_synonyms_df
# Out:
#                                                 Synonyms
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 14716                                                 []
# 14717                                                 []
# 14718  [1-propanol, propanol, Propan-1-ol, Propyl alc...
# 14719                                                 []
# 14720                                                 []
#
# [14721 rows x 1 columns]

# %%
import pandas as pd

# Create a DataFrame
all_synonyms_df = pd.DataFrame({'Synonyms': all_synonyms})

# Save to CSV
all_synonyms_df.to_csv('/content/all_synonyms.csv', index=False) # we downloaded this table in excel format, you have it in the folder

# %%
all_synonyms_df = pd.DataFrame({'Synonyms': all_synonyms})

# Concatenate along columns (axis=1)
final = pd.concat([chemicals_synonyms, all_synonyms_df], axis=1) # we downloaded this table in excel format, you have it in the folder

# %%
final.head() # There are two columns with synonyms because the first one was obtained using the Word2Vec algorithm in the previous method of database handling,
# we can drop one if we like
# Out:
#   IngredientIdentifier                                               Name  \
# 0               G00001  saccharomycesleuconostocapple fruitcarrot root...
# 1               G00002  lactobacilluscentella asiaticagleditsia sinens...
# 2               G00003  bacilluscordyceps sinensisganoderma lucidumino...
# 3               G00004                         ziziphus spinachristi leaf
# 4               G00005                          zingiber officinale water
#
#    Carcinogens  EndocrineDisruptors  Allergen  SkinIrritant Synonyms Synonyms
# 0        False                False     False         False      NaN       []
# 1        False                False     False         False      NaN       []
# 2        False                False     False         False      NaN       []
# 3        False                False     False         False      NaN       []
# 4        False                False     False         False      NaN       []

# %%
final.to_csv('/content/final.csv', index = False) # we downloaded this table in excel format, you have it in the folder

# %%
final.info
# Out:
# Synonyms      502
# Synonyms    14721
# dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14721 entries, 0 to 14720
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IngredientIdentifier  14721 non-null  object
#  1   Name                  14720 non-null  object
#  2   Carcinogens           14721 non-null  bool
#  3   EndocrineDisruptors   14721 non-null  bool
#  4   Allergen              14721 non-null  bool
#  5   SkinIrritant          14721 non-null  bool
#  6   Synonyms              502 non-null    object
#  7   Synonyms              14721 non-null  object
# dtypes: bool(4), object(4)
# memory usage: 517.7+ KB

# %% [markdown]
# ## We were not able to link the CAS numbers with our database; these are different compounds with differences in names. Web scraping is not always allowed to work with and databases are protected. We used web scraping to match synonyms with the chemicals names we already have, and have updated previosly. For further improvement, it remains to complete the database and find a way to link CAS numbers for each compound. Regarding Task 2, several libraries and algorithms for word matching were tried, and the one that remained yielded the best results. Training the model and accuracy checks take days. For the time we had as the conclusion, we can offer this.
